# %%
import numpy as np
import sys

# %%
t = np.load('constant/I_1_0.npy')
sys.getsizeof(t)
# Out:
# 1720

# %%
1720*10000
# Out:
# array([1.0000e+00, 1.0000e+00, 1.0000e+00, 8.0000e-01, 1.2000e+00,
#        1.5000e+00, 1.6000e+00, 1.9000e+00, 2.0000e+00, 2.4000e+00,
#        2.6000e+00, 2.8000e+00, 3.5000e+00, 3.2000e+00, 3.7000e+00,
#        4.0000e+00, 4.1000e+00, 4.9000e+00, 5.9000e+00, 6.3000e+00,
#        8.2000e+00, 9.0000e+00, 1.0600e+01, 1.2200e+01, 1.3500e+01,
#        1.5000e+01, 1.9000e+01, 2.2000e+01, 2.4100e+01, 2.6400e+01,
#        2.9300e+01, 3.3300e+01, 4.0000e+01, 4.5400e+01, 5.5400e+01,
#        6.2800e+01, 7.3800e+01, 8.4100e+01, 9.8700e+01, 1.1380e+02,
#        1.3020e+02, 1.4930e+02, 1.6800e+02, 1.8910e+02, 2.1390e+02,
#        2.4500e+02, 2.8400e+02, 3.1530e+02, 3.5800e+02, 4.0450e+02,
#        4.5760e+02, 5.1630e+02, 5.7890e+02, 6.4900e+02, 7.2910e+02,
#        8.1870e+02, 9.1360e+02, 1.0129e+03, 1.1210e+03, 1.2370e+03,
#        1.3477e+03, 1.4781e+03, 1.5948e+03, 1.7302e+03, 1.8531e+03,
#        1.9709e+03, 2.0856e+03, 2.1984e+03, 2.2944e+03, 2.3856e+03,
# ...
